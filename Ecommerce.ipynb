# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16, 8), subplot_kw=dict(aspect="equal"))

recipe = ["375  accessories",
          "315  home_appliance",
          "250  show_piece",
          "72  cloths"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} Quantity)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Product Category",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Category Wise Quantity Sold")
# Out:
# Text(0.5,1,'Category Wise Quantity Sold')

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16, 8), subplot_kw=dict(aspect="equal"))

recipe = ["375  Men",
          "315  Women",
          "250  Child",
         ]
data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} Quantity)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Product Category",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Gender Wise Category Quantity Sold")
# Out:
# Text(0.5,1,'Gender Wise Category Quantity Sold')

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16, 8), subplot_kw=dict(aspect="equal"))

recipe = ["14.2  accessories",
          "12.1  home_appliance",
          "8  show_piece",
          "3  cloths"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} Lac)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Product Category",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Category Wise Amount Sold(In Lac)")
# Out:
# Text(0.5,1,'Category Wise Amount Sold(In Lac)')
